# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('http://www.opap.gr/el/web/guest/joker-draw-results')
c = r.content

# %%
soup = BeautifulSoup(c,"html.parser")

# %%
soup.find_all('div')
# Out:
# [<div id="wrapper"> <div id="wrapper-top"> <div id="wrapper-top-content"> <div id="navigation-top"> <ul> <li id="top-languages"> <span> <a class="taglib-icon" href="http://www.opap.gr/el/web/guest/joker-draw-results?p_auth=01u370gB&amp;p_p_auth=ZWEUeT9S&amp;p_p_id=82&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_count=3&amp;_82_struts_action=%2flanguage%2fview&amp;languageId=el_GR" id="bvrs" lang="el-GR"> <img alt="Ελληνικά (Ελλάδα)" class="icon" src="/opap-gaming-theme/images/spacer.png" style="background-image: url('/opap-gaming-theme/images/language/.sprite.png'); background-position: 50% -132px; background-repeat: no-repeat; height: 11px; width: 16px;" title="Ελληνικά (Ελλάδα)"/> </a> </span> <span> <a class="taglib-icon" href="http://www.opap.gr/el/web/guest/joker-draw-results?p_auth=01u370gB&amp;p_p_auth=ZWEUeT9S&amp;p_p_id=82&amp;p_p_lifecycle=1&amp;p_p_state=normal&amp;p_p_mode=view&amp;p_p_col_count=3&amp;_82_struts_action=%2flanguage%2fview&amp;lang
# ...
