# %%
import pandas
df=pandas.read_excel("jokers/jokers.clean.xls")

# %%
df.set_index('Seq')
# Out:
#       1st  2nd  3rd  4th  5th  joker
# Seq
# 1      32   18   12    5   20      2
# 2      18    8   28   21   36      1
# 3       4   37    3   20   27     15
# 4       4    7   16   29   32     16
# 5      38   20   21   18   16     10
# 6       8   33    7   26   45      7
# 7      14   29    6    4   32      7
# 8      38   41    9   32   25      6
# 9      16   44   42   39   23     11
# 10     43    8   33   26   13     15
# 11      3   14    8   31   44      9
# 12     33   17   34   29   28     15
# 13     11    1   34   42   20     10
# 14     34   21    1   13    3     16
# 15     26   14    5   17   10     12
# 16      7   16   44   25   14     11
# 17     18   20   44   28   40      7
# 18     20    4    7   31   40     12
# 19      8    1   24    9    2      6
# 20      7   16   38    1   13      2
# 21     17   26   34   16   14     10
# 22     24    6   23    2   42     14
# 23     27   14   31   30   34     12
# 24      2   32   22   13   15     17
# ...

# %%
df.mean()
# Out:
# Seq      1030.500000
# 1st        23.151456
# 2nd        23.387379
# 3rd        22.978641
# 4th        23.092233
# 5th        23.302913
# joker      10.267961
# dtype: float64

# %%
print(df)
# Out:
#        Seq  1st  2nd  3rd  4th  5th  joker
# 0        1   32   18   12    5   20      2
# 1        2   18    8   28   21   36      1
# 2        3    4   37    3   20   27     15
# 3        4    4    7   16   29   32     16
# 4        5   38   20   21   18   16     10
# 5        6    8   33    7   26   45      7
# 6        7   14   29    6    4   32      7
# 7        8   38   41    9   32   25      6
# 8        9   16   44   42   39   23     11
# 9       10   43    8   33   26   13     15
# 10      11    3   14    8   31   44      9
# 11      12   33   17   34   29   28     15
# 12      13   11    1   34   42   20     10
# 13      14   34   21    1   13    3     16
# 14      15   26   14    5   17   10     12
# 15      16    7   16   44   25   14     11
# 16      17   18   20   44   28   40      7
# 17      18   20    4    7   31   40     12
# 18      19    8    1   24    9    2      6
# 19      20    7   16   38    1   13      2
# 20      21   17   26   34   16   14     10
# ...

# %%
import matplotlib.pyplot as plt
subset=df[1900:2060]

subset.plot(x='Seq', y='5th')

plt.show()

# %%
# Out:
#        Seq  1st  2nd  3rd  4th  5th  joker
# 2050  2051   16   27   22    4   38      6
# 2051  2052   13   29   27   41   14     19
# 2052  2053   26   45    3    5   43     13
# 2053  2054   43   32    8   20   24     10
# 2054  2055   17   27   34   42    2      9
# 2055  2056   38    1   28   21    9      2
# 2056  2057   27   45   41   37   20     20
# 2057  2058   30    5   41   31   26     17
# 2058  2059   19    7   14    1   18      8
# 2059  2060   36   41   33    2    9     20
