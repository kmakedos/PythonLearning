# %%
from glob import glob
import pandas
files=glob("*.xls")

# %%
df={}
for file in files:
    df[file] = pandas.read_excel(file)

# %%
for file in files:
    print(df[file])
# Out:
#    ΑΠΟΤΕΛΕΣΜΑΤΑ ΤΖΟΚΕΡ 2017 Unnamed: 1                    Unnamed: 2  \
# 0                     ΚΛΗΡ.     ΗΜ/ΝΙΑ  ΚΛΗΡΩΘΕΝΤΕΣ ΑΡΙΘΜΟΙ 5 ΑΠO 45
# 1                       NaN        NaN                           NaN
# 2                      1841   3/9/2017                            43
# 3                      1840  31/8/2017                            27
# 4                      1839  27/8/2017                            43
# 5                      1838  24/8/2017                            31
# 6                      1837  20/8/2017                            36
# 7                      1836  17/8/2017                            34
# 8                      1835  13/8/2017                             1
# 9                      1834  10/8/2017                            28
# 10                     1833   6/8/2017                             7
# 11                     1832   3/8/2017                            15
# 12                     1831  30/7/2017                            33
# ...
